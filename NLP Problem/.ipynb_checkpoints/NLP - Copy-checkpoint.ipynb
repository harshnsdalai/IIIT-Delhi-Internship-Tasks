# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Reading the Files

# %%
Train=pd.read_csv("V1.4_Training.csv",header=None)
Train.sample(10)
# Out:
#            0                                                  1  2
# 7596    1521  Ive also tried Bindings.Update - bit this does...  0
# 7313     817  There is information on this in the other MIDI...  0
# 7615    1554  Don't know if it is a specific number of devic...  0
# 761    868_2  "I am liking windows phone that I bought a cou...  0
# 7480    1217                       I'm aware of the sandboxing.  0
# 3147   0_719                      "Please take a note of this."  1
# 7952    9186  isn't it better to allow developers to change ...  1
# 1175  1286_3  "4 screenshots in two languages turns into 24 ...  0
# 5908    2275                   "There are no keyword searches."  0
# 1346  1366_4  "Originally posted by Sergiy (http://wpdev.use...  0

# %%
Test=pd.read_csv("SubtaskA_Trial_Test.csv",header=None)
Test.sample(10)
# Out:
#          0                                                  1  2
# 332  15521  "I'd like the ability for an application to be...  X
# 153  14181  "Please provide validation templates for Windo...  X
# 89   13721  "Barring that, at least allow for merged listi...  X
# 119  13911  "I'd like to be able to decorate my home scree...  X
# 397  15901  "currenty when you hit the Back button from th...  X
# 8    13192  "Add support for the biometric framework from ...  X
# 407  15963  "Support for word wrap or something would let ...  X
# 47   13383  "I keep getting birthday notifications a day t...  X
# 534  16334  "i have about 30 apps and it is already diffic...  X
# 263  15126  "Received from an MVP this week over email: It...  X

# %%
Test.drop(2,axis=1,inplace=True)
Test.sample(10)
# Out:
#           0                                                  1
# 272   15193  "It would be great if you could add .png suppo...
# 188   14382  "Imagine shopping apps being able to share a s...
# 21    13283  "Need an option to remove unused variables in ...
# 210   14492       "Visual Studio 11 and new Expression Blend."
# 71   135310  "It'd be great if we at least has the ability ...
# 518  162712  "This is VERY IMPORTANT for mobile websites be...
# 442  160712  "Tuenti is a social network as Facebook (in Sp...
# 585   16581  "Since windows phones are selling hot in count...
# 104   13811  "Quicker way to go to the bottom of the metro ...
# 24    13304  "Only after repairing the installation will th...

# %%
Eval=pd.read_csv("SubtaskA_EvaluationData.csv",header=None)
Eval.sample(6)
# Out:
#         0                                                  1  2
# 583  5556  Beacons are the next generation rulers in the ...  X
# 229  4595  Removing the support email from the webpage wo...  X
# 617  5649  It is crazy that such basic functionality is n...  X
# 152  3844  Specifically excellent mouse support means tha...  X
# 523  5353     My example: An interactive screen sharing app.  X
# 173  4097  Evidently the MediaComposition.SaveAsync() API...  X

# %%
Eval.drop(2,axis=1,inplace=True)
Eval.sample(10)
# Out:
#         0                                                  1
# 763  6098  if the location is slightly on the right the r...
# 133  3535  Currently i can only input plain text in toast...
# 21   9754  Add a boolean to CameraCaptureTask to indicate...
# 317  4844  I guess it is result of extremely short quantu...
# 318  4846  slider renders to extreme right (value 100) in...
# 130  3527  Something seems to have changed with loggingch...
# 434  5116  Each costumer may run a different version of t...
# 797  6209                     Now I created a universal app.
# 452  5169  if you try to open an file by file type associ...
# 692  5830  After changing to fullscreen and back the posi...

# %%
Eval.describe(include=['O'])
# Out:
#                           1
# count                   833
# unique                  833
# top     This is ridiculous.
# freq                      1

# %% [markdown]
# # Join the DataSets

# %%
combDf = Train.append([Eval], ignore_index=True)
combDf.sample(10)
# Out:
#             0                                                  1    2
# 2214   1784_8  "for example, once you add a location to MapPo...  1.0
# 972    1215_1  "As an app seller, I have to deal with dissati...  0.0
# 4705  1010_12  "After all, it is so easier to just allow to r...  0.0
# 233     735_1  "Provide an API to use Cortana services within...  1.0
# 5175       50  "With the new Windows UI Library now in pre-re...  0.0
# 8525     9796  Highly rated apps should appear near the top m...  NaN
# 6234     3263  "This led to a runtime crash that took a long ...  0.0
# 7506     1292  In visual studio if I select the container (a ...  0.0
# 534     814_8  "There are some bugs in notification center.If...  0.0
# 8971     5207  We have several Instruments that implement an ...  NaN

# %% [markdown]
# # Label the Columns

# %%
combDf.columns=['id','sentence','label']
combDf.sample(10)
# Out:
#           id                                           sentence  label
# 3997  0_1904                           "It's really annoying.""    0.0
# 1047  1246_1  "Can you get rid of this space to enable more ...    1.0
# 4574  978_12  "Please, to have competitive advantage, i woul...    1.0
# 6049    2742  "I understand WinAppDriver does not currently ...    0.0
# 5361     492  "Local release builds created with the native ...    0.0
# 2271  1805_1  "it would be helpfull to have a passwordBox li...    0.0
# 5448     745  "Other competitors such as Citrix and HP have ...    0.0
# 8254    2259  Plus as I read in the docs this can degrade vi...    0.0
# 7525    1342  In trying to use SHA2 Timestamp(current Micros...    0.0
# 8684    4178  Reaper and other desktop programs are displayi...    NaN

# %% [markdown]
# # Checking if their is any missing value

# %%
combDf.describe(include=['O'])
combDf["label"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
combDf.shape
# Out:
# (9333, 3)

# %% [markdown]
# # Conveting the sentence to LowerCase

# %%
combDf["sentence"] = combDf["sentence"].str.lower()
combDf.sample(7)
# Out:
#          id                                           sentence  label
# 708   855_1  "the bottom could be quick links while the top...    1.0
# 7986   9398  it's not healthy to keep several accounts that...    0.0
# 274   747_9  "now my killer app has to wait for windows to ...    0.0
# 6249   3299  "unfortunately i do not own a xbox nor would g...    0.0
# 4970   1303  "wait one minute (so the clock shows a new min...    1.0
# 7213    602  also phone has support but is painful to use w...    0.0
# 5033   1873  "provide funtionality similar to currentappsim...    1.0

# %% [markdown]
# # Defining function to remove patterns

# %%
import re
def remove_pat(s1, pat, nstr):
    return re.sub(pat, nstr, s1)

# %% [markdown]
# # Removing special Characters

# %%
combDf["new"] = np.vectorize(remove_pat)(combDf["sentence"], "[^a-zA-Z#_]+", " ")
combDf.sample(5)
# Out:
#            id                                           sentence  label  \
# 1335  1361_12  "will screen shots work by default for windows...    0.0
# 3519   0_1422  "i understand why you might do this for the fr...    1.0
# 1452  1449_13  "the only possibility to search them is to use...    0.0
# 7905     8885  it would be extremely helpful if the reminder/...    1.0
# 506     806_5  "now i can get it standing outside the wall fr...    0.0
#
#                                                     new
# 1335   will screen shots work by default for windows...
# 3519   i understand why you might do this for the fr...
# 1452   the only possibility to search them is to use...
# 7905  it would be extremely helpful if the reminder ...
# 506    now i can get it standing outside the wall fr...

# %% [markdown]
# #  Removing the words whose length is less than 3

# %%
combDf["new"] = np.vectorize(remove_pat)(combDf["new"], r"\b[a-z]{1,2}\b", " ")
combDf.sample(10)
# Out:
#           id                                           sentence  label  \
# 7453    1162  on windows 10 uwp apps if you rapidly click or...    0.0
# 803    880_1  "i want to implement certificate pinning for a...    1.0
# 3707  0_1611  "please enhance the new back up function (http...    1.0
# 6719    4563  "this leads the user to have to type again the...    0.0
# 3841  0_1745      "i *should* be able to use feedly in luakit."    1.0
# 65     679_3  "on my lumia 920 it takes significantly longer...    0.0
# 166    702_1  "when using headphones, music will pause if co...    0.0
# 2624   0_131  "typeconverter is helpful because it allows th...    0.0
# 5214     149             "so this i have been thinking so far:"    0.0
# 5752    1716                          "powershell stack trace:"    0.0
#
#                                                     new
# 7453    windows uwp apps   you rapidly click   unint...
# 803      want   implement certificate pinning for ad...
# 3707   please enhance the new back   function http b...
# 6719   this leads the user   have   type again the w...
# 3841               should   able   use feedly   luakit
# 65         lumia   takes significantly longer     th...
# 166    when using headphones music will pause   cort...
# 2624   typeconverter   helpful because   allows the ...
# 5214                   this   have been thinking   far
# 5752                            powershell stack trace

# %% [markdown]
# # Combining all sentences

# %%
import matplotlib.pyplot as plt
all_words = ' '.join([text for text in combDf['new']])
all_words
# Out:
# ' please enable removing language code from the dev center language history for example   you ever selected   and     laguages and you published this xap   the store then   causes tile localization   show the     default tile localization which   bad   note   your csproj file there     supportedcultures entry like this supportedcultures           supportedcultures when   removed the   language code and published   new xap version the old xap version still remains   the store with replaced and unpublished   wich means the new version not fully replaced the old version and this causes   very serious problems   some     users will still receive the old xap version     app   the store randomly gives the old xap   the new xap version     app     app has     version and     version xap   the same submission   the   xap works only     and the   xap works only for     sometimes the store gives the wrong   xap version     app   windows phone users     should     option   remove the   language code from   app language history     option   completly replace fully replace the prevoius   xap     currently   you ever mistakenly selected     language than you will       very bad situation forever you can live with the wrong tile displayed for russian language   the store the english one   you can publish   update with the removed   language but this update will not fully replace the old version and you will   truble   the store will randomly deliver the old wrong version   your xap     write   lot support ticket   this but   one really cares   this issue   the engineering team can solve this issue   they   one   the following   provide   workaround for removing the   language from the language history   have   need for   culture just for     but there     way   remove   from the language history   you ever posted your app with   language support     add and implement   appreslib dll xxxx mui for the   language culture   the documentation appreslib dll xxxx mui exist only for     and not for   culture http msdn microsoft com     library windowsphone develop       aspx thanks tom please enable removing language code from the dev center language history for example   you ever selected   and     laguages and you published this xap   the store then   causes tile localization   show the     default tile localization which   bad   wich means the new version not fully replaced the old version and this causes   very serious___ more   when   driving   car and need   make call     times the phone use vocal commands for starting bing search instead   call contact   but     press power button and unlock device and open phone and say call person name device start calling correctly   this   driving mode activated   also   italian translation after reading sms the device say fatto for ending operation but work only     say   finito       say fatto vocal command unrecognized   other little bugs with   lumia before first   upgrade work fine with vocal commands but from first upgrade   now   bad   don   recognize commands   but   old   work fine using same   sony car stereo   other little bugs with   lumia before first   upgrade work fine with vocal commands but from___ more   outlook color schemes   settings current live tile size and more   open the network settings and tap   call settings   hit the power button       sleep mode   wait for minutes and switch   the mobile again   the window will   blank with only heading       reproducible   lumia cyan update     always use this feature please fix asap   seems there     issue with the   card     preview   its getting annoying please fix this       been working     lob for   field   engineering civil structural   the point     make the app universal across devices   that our engineers   not have   spend too much time learning and relearning the controls   and because the same app runs   tablets and     our engineers can work   the field come back   their office and continue working with the same data   their   ...

# %% [markdown]
# # Removing Stop Words

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(all_words) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  
print(filtered_sentence)
# Out:
# ['please', 'enable', 'removing', 'language', 'code', 'dev', 'center', 'language', 'history', 'example', 'ever', 'selected', 'laguages', 'published', 'xap', 'store', 'causes', 'tile', 'localization', 'show', 'default', 'tile', 'localization', 'bad', 'note', 'csproj', 'file', 'supportedcultures', 'entry', 'like', 'supportedcultures', 'supportedcultures', 'removed', 'language', 'code', 'published', 'new', 'xap', 'version', 'old', 'xap', 'version', 'still', 'remains', 'store', 'replaced', 'unpublished', 'wich', 'means', 'new', 'version', 'fully', 'replaced', 'old', 'version', 'causes', 'serious', 'problems', 'users', 'still', 'receive', 'old', 'xap', 'version', 'app', 'store', 'randomly', 'gives', 'old', 'xap', 'new', 'xap', 'version', 'app', 'app', 'version', 'version', 'xap', 'submission', 'xap', 'works', 'xap', 'works', 'sometimes', 'store', 'gives', 'wrong', 'xap', 'version', 'app', 'windows', 'phone', 'users', 'option', 'remove', 'language', 'code', 'app', 'language', 'history', 'option', 'completly', 'replace', 'fully', 'replace', 'prevoius', 'xap', 'currently', 'ever', 'mistakenly', 'selected', 'language', 'bad', 'situation', 'forever', 'live', 'wrong', 'tile', 'displayed', 'russian', 'language', 'store', 'english', 'one', 'publish', 'update', 'removed', 'language', 'update', 'fully', 'replace', 'old', 'version', 'truble', 'store', 'randomly', 'deliver', 'old', 'wrong', 'version', 'xap', 'write', 'lot', 'support', 'ticket', 'one', 'really', 'cares', 'issue', 'engineering', 'team', 'solve', 'issue', 'one', 'following', 'provide', 'workaround', 'removing', 'language', 'language', 'history', 'need', 'culture', 'way', 'remove', 'language', 'history', 'ever', 'posted', 'app', 'language', 'support', 'add', 'implement', 'appreslib', 'dll', 'xxxx', 'mui', 'language', 'culture', 'documentation', 'appreslib', 'dll', 'xxxx', 'mui', 'exist', 'culture', 'http', 'msdn', 'microsoft', 'com', 'library', 'windowsphone', 'develop', 'aspx', 'thanks', 'tom', 'please', 'enable', 'removing', 'language', 'code', 'dev', 'center', 'language', 'history', 'example', 'ever', 'selected', 'laguages', 'published', 'xap', 'store', 'causes', 'tile', 'localization', 'show', 'default', 'tile', 'localization', 'bad', 'wich', 'means', 'new', 'version', 'fully', 'replaced', 'old', 'version', 'causes', 'serious___', 'driving', 'car', 'need', 'make', 'call', 'times', 'phone', 'use', 'vocal', 'commands', 'starting', 'bing', 'search', 'instead', 'call', 'contact', 'press', 'power', 'button', 'unlock', 'device', 'open', 'phone', 'say', 'call', 'person', 'name', 'device', 'start', 'calling', 'correctly', 'driving', 'mode', 'activated', 'also', 'italian', 'translation', 'reading', 'sms', 'device', 'say', 'fatto', 'ending', 'operation', 'work', 'say', 'finito', 'say', 'fatto', 'vocal', 'command', 'unrecognized', 'little', 'bugs', 'lumia', 'first', 'upgrade', 'work', 'fine', 'vocal', 'commands', 'first', 'upgrade', 'bad', 'recognize', 'commands', 'old', 'work', 'fine', 'using', 'sony', 'car', 'stereo', 'little', 'bugs', 'lumia', 'first', 'upgrade', 'work', 'fine', 'vocal', 'commands', 'from___', 'outlook', 'color', 'schemes', 'settings', 'current', 'live', 'tile', 'size', 'open', 'network', 'settings', 'tap', 'call', 'settings', 'hit', 'power', 'button', 'sleep', 'mode', 'wait', 'minutes', 'switch', 'mobile', 'window', 'blank', 'heading', 'reproducible', 'lumia', 'cyan', 'update', 'always', 'use', 'feature', 'please', 'fix', 'asap', 'seems', 'issue', 'card', 'preview', 'getting', 'annoying', 'please', 'fix', 'working', 'lob', 'field', 'engineering', 'civil', 'structural', 'point', 'make', 'app', 'universal', 'across', 'devices', 'engineers', 'spend', 'much', 'time', 'learning', 'relearning', 'controls', 'app', 'runs', 'tablets', 'engineers', 'work', 'field', 'come', 'back', 'office', 'continue', 'working', 'data', 'windows', 'windows', 'phone', 'universal', 'app', 'hoping', 'adapt', 'app', 'windows', 'phone', 'well', 'saved', 'live', 'data', 'saved', 'onedrive', 'allow', ...

# %% [markdown]
# # Creating Frequency List

# %%
import nltk
freq = nltk.FreqDist(filtered_sentence) 
for key,val in freq.items(): 
    print (str(key) + ':' + str(val))
# Out:
# please:430
# enable:67
# removing:16
# language:89
# code:252
# dev:127
# center:104
# history:31
# example:212
# ever:24
# selected:49
# laguages:4
# published:36
# xap:26
# store:423
# causes:28
# tile:78
# localization:16
# show:140
# default:93
# bad:47
# note:35
# csproj:2
# file:282
# supportedcultures:3
# entry:20
# like:778
# removed:26
# new:348
# version:179
# old:57
# still:140
# remains:12
# replaced:11
# unpublished:4
# wich:7
# means:65
# fully:30
# serious:16
# problems:43
# users:250
# receive:37
# app:1523
# randomly:8
# gives:27
# submission:33
# works:108
# sometimes:49
# wrong:48
# windows:1146
# phone:666
# option:194
# remove:69
# completly:4
# replace:15
# prevoius:2
# currently:326
# mistakenly:1
# situation:20
# forever:3
# live:68
# displayed:53
# russian:4
# english:18
# one:399
# publish:21
# update:165
# truble:2
# deliver:6
# write:55
# lot:130
# support:361
# ticket:4
# really:153
# cares:3
# issue:146
# engineering:3
# team:30
# solve:14
# following:57
# provide:178
# workaround:14
# need:289
# culture:7
# way:352
# posted:13
# add:424
# implement:66
# appreslib:4
# dll:14
# xxxx:4
# mui:4
# documentation:39
# exist:27
# http:171
# msdn:69
# microsoft:385
# com:315
# library:94
# windowsphone:29
# develop:54
# aspx:36
# thanks:36
# tom:3
# serious___:1
# driving:3
# car:4
# make:346
# call:133
# times:63
# use:536
# vocal:4
# commands:18
# starting:21
# bing:42
# search:175
# instead:130
# contact:71
# press:48
# power:32
# button:179
# unlock:24
# device:191
# open:195
# say:53
# person:18
# name:160
# start:96
# calling:27
# correctly:30
# mode:90
# activated:5
# also:316
# italian:4
# translation:6
# reading:49
# sms:36
# fatto:2
# ending:3
# operation:12
# work:243
# finito:1
# command:35
# unrecognized:1
# little:15
# bugs:18
# lumia:53
# first:109
# upgrade:14
# fine:61
# recognize:6
# using:404
# sony:1
# stereo:4
# from___:1
# outlook:14
# color:53
# schemes:3
# settings:89
# current:117
# size:70
# network:72
# tap:27
# hit:9
# sleep:1
# wait:34
# minutes:27
# switch:45
# mobile:135
# window:100
# blank:13
# heading:2
# reproducible:2
# cyan:2
# always:79
# feature:164
# fix:71
# asap:5
# seems:98
# card:53
# preview:38
# getting:53
# annoying:45
# working:121
# lob:6
# field:30
# civil:1
# structural:1
# point:65
# universal:82
# across:26
# devices:124
# engineers:6
# spend:10
# much:119
# time:276
# learning:10
# relearning:2
# controls:95
# runs:16
# tablets:6
# come:19
# back:140
# office:42
# continue:19
# data:247
# hoping:5
# adapt:4
# well:109
# saved:40
# onedrive:20
# allow:351
# roaming:4
# found:96
# picker:23
# access:238
# futureaccesslist:14
# aspect:7
# alone:11
# prevents:10
# adaptation:1
# platform:99
# folder:97
# location:57
# stored:21
# locally:12
# winrt:63
# otherwise:19
# real:50
# are___:1
# far:34
# tried:53
# three:24
# different:132
# apps:790
# pre:13
# photos:25
# needs:76
# fixing:4
# number:116
# priority:10
# would:983
# nice:131
# give:90
# developers:262
# put:54
# payment:31
# hold:16
# reach:17
# appropriate:8
# threshold:8
# top:83
# next:53
# due:27
# theres:1
# bug:93
# push:29
# service:95
# i__m:3
# connection:56
# get:308
# notifications:43
# wifi:53
# server:73
# turn:38
# manually:41
# gdr:4
# system:158
# recognized:4
# automaticly:4
# cellular:11
# everytime:8
# doesn__t:1
# try:80
# insert:6
# bank:10
# account:161
# error:86
# validation:11
# country:35
# think:148
# correct:38
# paypal:7
# money:20
# another:119
# want:299
# pay:26
# extra:22
# costs:4
# tax:4
# plan:6
# validate:3
# according:23
# post:67
# voted:2
# change:141
# voted___:1
# report:44
# purchases:14
# today:44
# noticed:30
# every:123
# line:45
# item:70
# shows:52
# certainly:8
# case:92
# vision:15
# lens:3
# camera:46
# pinnable:2
# quick:22
# cortana:45
# screen:228
# left:85
# music:84
# perhaps:25
# able:316
# directly:76
# facebook:53
# people:110
# hub:42
# comment:16
# walls:1
# without:178
# enter:33
# text:181
# messages:39
# fly:6
# takes:49
# significantly:5
# longer:26
# slow:30
# bring:43
# simplicity:1
# efficiency:4
# building:23
# web:120
# application:330
# single:45
# page:212
# applications:145
# url:53
# www:55
# contoso:2
# #:73
# display:77
# refresh:11
# load:37
# check:57
# great:188
# remoteid:4
# calendars:9
# appointments:7
# easier:37
# sync:28
# reason:59
# sent:23
# email:89
# received:13
# developer:245
# know:151
# however:130
# easily:50
# fixed:46
# writing:37
# tilebrush:5
# class:97
# missing:46
# tilemode:1
# view:90
# properties:48
# present:27
# frameworks:10
# wpf:66
# silverlight:56
# image:108
# tiling:3
# properly:24
# tons:6
# requests:8
# past:10
# years:22
# see:272
# thread:30
# social:39
# forums:56
# windowsapps:6
# bdbee:1
# windowsuixamlmediaimagebrush:1
# forum:34
# winappswithcsharp:1
# lockscreen:13
# attribute:20
# separated:3
# attributes:9
# necessary:21
# widebackcontent:1
# flip:5
# generated:30
# custom:90
# trying:59
# api:312
# contacts:47
# namespace:9
# applicationmodel:17
# expected:41
# ioexception:1
# pickcontactasync:5
# strange:12
# since:129
# expecting:6
# least:88
# launched:13
# problem:168
# establishing:1
# contract:10
# checked:6
# permission:20
# enabled:27
# package:60
# appxmanifest:6
# che:3
# instaed:2
# firstname:10
# lastname:12
# empty:19
# importantdates:1
# birthday:2
# set:200
# low:34
# values:22
# navigate:20
# right:179
# maybe:64
# something:136
# broken:18
# is___:4
# although:17
# possible:210
# define:12
# etw:11
# events:55
# generate:31
# publicly:2
# available:151
# tooling:12
# tools:39
# collection:21
# predefined:3
# profiles:5
# certain:38
# appears:48
# tell:36
# collect:10
# event:102
# sources:10
# net:83
# based:76
# diagnostics:6
# tracing:3
# eventsource:2
# used:161
# appear:36
# moment:37
# actually:56
# record:17
# trace:8
# clear:15
# duplicate:10
# wpdev:17
# uservoice:29
# suggestions:27
# logging:14
# reply:19
# points:20
# already:128
# log:38
# ability:124
# alongside:7
# provided:27
# activity:11
# fits:3
# behaviour:11
# you___:1
# integration:46
# fast:34
# pictures:28
# photo:45
# albums:9
# long:52
# happened:12
# good:149
# could:383
# minimize:11
# maximize:10
# purchased:14
# smooth:8
# slowly:2
# moving:18
# towards:6
# smsreceived:1
# notified:5
# phonereveived:1
# moreover:3
# better:110
# read:119
# help:64
# related:48
# android:151
# mapicon:10
# sdk:83
# zindex:1
# tapped:5
# accessible:15
# messaging:21
# join:2
# message:98
# full:84
# interaction:13
# send:91
# delete:62
# etc:172
# uses:55
# others:35
# thing:46
# developper:2
# ablity:1
# apis:74
# synchronize:5
# clock:13
# via:123
# internet:40
# countries:20
# provider:8
# services:47
# include:59
# deactivate:2
# tracking:19
# protection:4
# lists:15
# tpl:2
# drive:28
# usage:42
# selective:2
# rogue:2
# sites:16
# sense:49
# control:304
# desktop:186
# understand:63
# coming:13
# cortanan:1
# things:67
# understanding:10
# dates:5
# planning:4
# agenda:3
# done:57
# nicely:3
# pivot:24
# panorama:13
# options:62
# disable:37
# wrapping:6
# scroll:42
# viewer:17
# overscrolling:2
# effect:26
# program:27
# livesdk:3
# bool:3
# connected:44
# false:17
# var:11
# authclient:4
# liveauthclient:1
# liveloginresult:3
# result:46
# await:10
# loginasync:3
# string:37
# signin:3
# skydrive:9
# status:25
# liveconnectsessionstatus:1
# true:17
# connectclient:2
# liveconnectclient:1
# session:7
# meresult:2
# getasync:1
# dynamic:9
# medata:1
# catch:17
# liveauthexception:1
# liveconnectexception:1
# generic:17
# exception:58
# obtain:5
# object:40
# reference:19
# istance:2
# row:20
# null:14
# wrote:5
# ___:23
# recover:1
# files:155
# hoello:1
# forced:15
# resume:12
# swipe:34
# tunes:1
# hastilly:1
# submitted:16
# transparent:13
# realised:1
# later:47
# causing:8
# issues:51
# secondary:14
# tiles:51
# pretty:17
# killed:1
# looks:56
# abandon:2
# previous:35
# customers:32
# cant:23
# wpappmanifest:2
# untick:2
# run:107
# icon:48
# nfc:21
# capable:11
# phones:47
# wallet:4
# locations:5
# readers:14
# google:151
# almost:20
# youtube:39
# mcd:1
# destroy:4
# argument:9
# apple:44
# going:43
# soon:16
# close:46
# gap:3
# functionality:82
# create:253
# edit:24
# document:20
# thereby:9
# integrate:20
# openxml:2
# __:6
# primary:19
# interop:12
# assembly:7
# classes:34
# win:103
# productive:2
# businesses:4
# pubcenter:8
# claims:1
# interstitials:3
# bigger:8
# formats:24
# networks:17
# break:8
# game:32
# therefore:23
# important:46
# fill:9
# rate:19
# allowing:56
# prefetch:2
# optimise:4
# strategy:3
# house:12
# request:75
# cpu:9
# gpu:4
# style:59
# part:63
# font:33
# italic:2
# segoe:5
# rendered:9
# bolder:1
# rest:14
# cbd:1
# cce:1
# bold:2
# winappswithhtml:2
# screenshots:41
# seen:20
# quite:32
# marked:14
# completed:9
# cards:19
# tags:23
# level:40
# deceptive:1
# capabilities:20
# reality:9
# specific:62
# type:86
# tag:20
# products:13
# existing:56
# several:51
# types:34
# mifare:3
# ulc:3
# calypso:3
# desfire:3
# even:202
# added:61
# chipset:1
# be___:2
# supremely:1
# developing:42
# certification:51
# purchase:22
# product:15
# sure:50
# needed:50
# merely:3
# price:37
# key:40
# cert:6
# process:85
# instantly:6
# porting:8
# feel:27
# template:31
# awesome:25
# increase:19
# productivity:4
# pages:38
# usercontrol:4
# folders:23
# let:97
# face:5
# unless:14
# platforms:57
# end:48
# creating:37
# versions:55
# project:77
# user:507
# original:36
# stated:5
# names:30
# usercontrols:1
# rule:10
# deal:20
# settingsflyouts:1
# took:10
# replicate:2
# automatic:12
# likewise:1
# bottom:39
# bars:11
# translated:4
# automatically:62
# buttons:32
# styles:11
# xaml:167
# whatever:12
# contains:32
# templates:12
# believe:31
# kinds:5
# measures:1
# taken:11
# remember:11
# ported:6
# simple:69
# arrives:4
# matching:11
# achieves:1
# may:90
# matter:14
# anymore:16
# additions:2
# pages___:1
# wished:1
# merging:2
# obviously:11
# includes:15
# headphones:7
# pause:10
# cortanta:3
# notifies:2
# incoming:15
# play:70
# respond:12
# notification:86
# podacasts:1
# inaudibly:1
# background:160
# interact:12
# media:79
# playing:33
# paused:8
# interacting:2
# trial:24
# built:67
# enforcement:2
# prompting:5
# disabling:8
# choose:45
# pick:12
# days:49
# last:44
# everything:28
# care:8
# uninstalls:5
# tracks:7
# fact:18
# contrast:5
# world:32
# indicates:7
# track:28
# install:69
# whether:32
# installs:4
# idea:79
# adding:75
# feels:7
# pray:2
# absolutely:14
# love:45
# implementation:31
# two:96
# stores:13
# combining:2
# days___:1
# flashlight:1
# recent:23
# places:13
# suggestedstartlocation:13
# fileopenpicker:8
# hard:56
# calendar:48
# customize:9
# day:37
# basing:2
# upon:16
# requirement:15
# less:45
# frustrating:22
# hints:5
# failed:21
# reports:20
# tackle:3
# obvious:8
# arise:3
# restrictions:10
# find:131
# solution:47
# never:42
# heard:9
# pointers:2
# keywords:15
# efficiently:2
# nearly:14
# effortlessly:1
# easy:62
# dark:15
# light:16
# theme:24
# black:19
# white:23
# hence:3
# readable:8
# occured:4
# multiple:63
# tens:3
# four:5
# lines:30
# probably:27
# thousands:17
# hour:7
# searching:13
# efficient:5
# might:61
# visibility:18
# resources:16
# phonedarkthemevisibility:1
# similar:91
# brush:7
# phonebackgroundbrush:1
# additional:44
# links:29
# closes:5
# nothing:31
# implementing:10
# auto:44
# upload:51
# clickable:1
# menu:62
# within:70
# information:90
# ebba:1
# dae:1
# launching:8
# wpdevelop:9
# release:51
# lock:51
# treat:3
# devs:36
# equally:1
# mediastreamsource:5
# stream:17
# audio:88
# sound:23
# flickering:3
# components:19
# stack:24
# overflow:10
# ing:1
# discussion:3
# wpapps:3
# fae:1
# sample:45
# source:45
# https:157
# libflac:1
# codeplex:3
# publishing:21
# bundle:4
# unfortunately:42
# prices:6
# marketplace:47
# tier:2
# county:1
# separately:13
# exchange:12
# calculate:6
# willing:6
# charge:6
# canada:3
# europe:2
# argentina:2
# indonesia:1
# south:3
# africa:4
# rates:5
# checkbox:3
# fee:14
# normal:26
# percentage:6
# receipts:1
# deducted:1
# calculating:3
# proceeds:2
# markets:10
# chile:1
# colombia:1
# costa:1
# rica:1
# malaysia:1
# mexico:1
# peru:1
# applies:8
# alternative:18
# methods:23
# carrier:6
# billing:2
# credit:15
# transactions:6
# we___:1
# identity:4
# bit:34
# click:104
# splash:9
# making:53
# consumers:11
# actual:26
# screens:13
# impression:6
# consider:35
# lags:5
# uris:8
# external:23
# notify:11
# decide:14
# allowed:50
# scriptnotify:3
# extend:16
# mediaelement:9
# videos:51
# collaborate:1
# challenge:2
# unleash:1
# reproduce:18
# wbmp:3
# writeablebitmap:5
# setsourceasync:1
# comes:20
# picture:35
# larger:16
# pixelwidth:6
# pixelheight:6
# pixelbuffer:4
# length:14
# totally:10
# buffer:28
# shoud:1
# value:73
# decides:6
# property:116
# inconsistent:4
# era:2
# tuners:1
# digital:4
# multitasking:8
# seeing:13
# video:154
# mini:13
# calc:2
# browse:10
# limit:32
# implementable:3
# interface:44
# expose:12
# worldwide:7
# extends:1
# sharing:23
# list:149
# useful:105
# become:25
# share:46
# chrome:69
# extension:56
# mac:24
# ios:91
# listview:58
# grouped:9
# items:94
# grid:19
# selectionmode:2
# none:19
# isitemclickenabled:1
# itemssource:6
# binding:61
# staticresource:4
# csvlist:1
# groupstyle:8
# headertemplate:3
# datatemplate:16
# border:12
# borderthickness:1
# borderbrush:1
# blue:6
# textblock:8
# margin:6
# subheadertextblockstyle:1
# foreground:13
# itemtemplate:9
# itemcontainerstyle:2
# targettype:1
# listviewitem:1
# setter:4
# horizontalcontentalignment:1
# stretch:5
# definition:6
# groupheader:2
# wide:12
# width:15
# actualwidth:4
# elementname:2
# hubevidenza:2
# oneway:3
# root:4
# container:11
# hubsection:1
# content:136
# header:25
# group:41
# header___:1
# installed:67
# acutally:1
# respect:5
# regional:4
# format:41
# started:21
# emulator:81
# configuration:16
# testing:27
# purpose:15
# german:8
# region:15
# irish:2
# wish:26
# datetime:3
# wants:34
# mean:16
# langauge:1
# chose:9
# timestamps:3
# setting:58
# made:63
# to___:2
# model:12
# future:31
# introduces:3
# extensibility:6
# framework:29
# allows:84
# third:37
# party:57
# feed:72
# locked:19
# select:62
# given:37
# socialintegration:1
# limited:46
# developed:25
# word:45
# must:67
# measured:1
# sideloading:3
# emulators:19
# valuable:4
# feedback:63
# exciting:5
# scenario:30
# for___:2
# export:12
# projects:22
# instructions:5
# site:47
# successfully:8
# storeapp:1
# appstudio:1
# windows_:1
# _anycpu:1
# appx:29
# isvisible:1
# mvvm:13
# possibly:10
# named:7
# parent:7
# popup:15
# revealed:2
# suitable:3
# got:39
# figured:3
# company:40
# killer:1
# sets:9
# speakers:3
# microphones:3
# separate:26
# speaker:3
# whole:34
# happy:14
# convenient:15
# swiping:9
# gestures:8
# fun:7
# method:66
# difference:14
# launch:46
# launches:6
# posting:11
# picasa:1
# requested:10
# best:51
# many:162
# editing:15
# market:38
# pass:26
# choice:13
# supports:43
# function:94
# filter:21
# crop:4
# opened:34
# edited:3
# pickers:2
# perform:11
# tasks:34
# experience:71
# keeping:5
# sandbox:7
# mentality:1
# app___:1
# increbible:1
# whistle:1
# clap:1
# hands:3
# pattern:9
# preseted:1
# owner:6
# dont:18
# buddy:2
# around:42
# tiny:1
# outline:1
# lettering:1
# written:21
# pgn:2
# lockscreens:2
# half:11
# song:20
# info:36
# xbox:68
# swap:5
# player:51
# sideways:1
# mail:32
# seperate:4
# accounts:36
# screen___:1
# final:3
# companies:12
# sales:12
# estimate:2
# purposes:6
# brought:3
# transitions:6
# native:86
# animations:27
# opening:29
# closing:12
# isstaggeringenabled:1
# isstaggerelement:1
# commonnavigationinfo:1
# keep:58
# conditions:4
# proper:14
# representing:6
# high:38
# quality:23
# images:71
# symbols:5
# modern:15
# simply:54
# ugly:5
# icons:30
# pixelated:1
# pirated:1
# misleading:2
# games:35
# free:50
# offers:9
# promotions:1
# misses:1
# category:26
# showing:43
# gone:11
# red:7
# stripe:1
# deals:1
# updates:30
# body:24
# onload:3
# april:2
# backup:9
# restore:14
# yesterday:7
# mostly:7
# nokia:34
# examples:9
# maps:18
# backed:6
# bought:9
# restored:4
# either:71
# sign:15
# saying:8
# course:19
# ringtone:7
# glance:4
# goes:26
# night:6
# recently:17
# private:15
# client:54
# certificate:31
# surprised:7
# returns:28
# async:14
# thought:17
# imported:3
# pfx:6
# clearly:5
# improve:29
# flow:10
# clientcert:8
# ensurecertficatesasync:2
# logger:7
# checking:8
# loaded:30
# return:62
# winjs:10
# promise:3
# certquery:8
# certificates:24
# certificatequery:2
# friendlyname:3
# certificatestores:3
# findallasync:4
# certs:8
# storage:44
# storagefile:11
# getfilefromapplicationuriasync:1
# fileio:1
# readbufferasync:1
# security:39
# cryptography:3
# cryptographicbuffer:1
# encodetobase:1
# installing:22
# certificateenrollmentmanager:2
# importpfxdataasync:1
# xxxxx:2
# exportoption:1
# notexportable:1
# keyprotectionlevel:1
# noconsent:1
# installoptions:1
# omitted:1
# else:28
# query:11
# fetch:3
# calls:20
# httpclient:3
# breaking:5
# success:9
# continuation:2
# returned:23
# consideration:6
# return___:1
# wifis:1
# usable:10
# arabic:6
# keyboard:59
# explorer:47
# opera:2
# sending:20
# attach:13
# software:57
# sky:2
# common:28
# possibility:39
# approaching:1
# reverse:3
# leaving:12
# operational:2
# systems:18
# enterprise:21
# signed:12
# touch:53
# kiosk:5
# machine:36
# usb:34
# installation:21
# payoneer:1
# earnings:1
# attachment:6
# grip:1
# xperia:1
# snapdragon:1
# recording:14
# require:23
# factory:9
# createwicbitmaprendertarget:1
# strangely:2
# supported:72
# rendering:21
# direct:25
# quote:3
# oem:2
# docs:22
# welcome:4
# windows_phone_:1
# ___windows:1
# drivers:15
# umdf:6
# syntax:3
# kmdf:1
# makers:4
# oems:1
# becoming:6
# pcs:4
# hardware:43
# extensions:19
# structure:2
# sensor:4
# designed:12
# iphone:32
# safe:18
# harming:1
# thus:14
# guarding:1
# penetrating:1
# registered:11
# driver:26
# approval:2
# mentioned:11
# harming___:1
# downloaded:26
# typically:5
# delay:10
# hrs:2
# per:35
# amazing:10
# performing:4
# blazing:1
# speeds:5
# benchmarked:1
# management:22
# place:55
# albeit:2
# dashboard:36
# reporting:11
# somebody:4
# accountable:1
# attention:9
# date:41
# frozes:1
# hangs:4
# big:34
# happens:36
# clicking:17
# opens:21
# linking:4
# except:14
# dial:4
# pad:2
# shown:43
# hav:2
# jack:4
# adds:11
# msn:3
# cell:7
# observations:1
# gets:42
# hang:3
# receiving:6
# cells:1
# rings:2
# normally:14
# pickup:2
# state:42
# force:20
# mute:11
# smoothly:5
# ringer:13
# mutes:1
# restart:16
# required:38
# observed:3
# functions:26
# fantastic:9
# windows___:2
# apologies:2
# community:21
# upgrading:4
# latest:33
# unstable:5
# zero:11
# shuts:2
# weirdly:1
# mno:3
# homepage:6
# particularly:10
# speed:13
# helps:12
# details:50
# handset:2
# operator:8
# ceullar:2
# updating:15
# earlier:7
# occurs:21
# switching:13
# dns:16
# toggling:2
# airline:2
# restores:2
# apn:2
# identical:3
# profile:10
# selecting:12
# max:7
# marginally:1
# stopped:10
# home:31
# detecting:1
# tethering:1
# called:43
# confirmed:7
# block:17
# reset:26
# including:28
# soft:10
# vpn:5
# sim:13
# official:23
# nanosim:1
# reseating:1
# turning:5
# amke:1
# cheers:3
# alan:1
# fine___:1
# ease:6
# archive:9
# zip:15
# contain:9
# meta:3
# xml:18
# supporting:15
# ingest:1
# provides:34
# capability:43
# itunes:1
# connect:46
# languagesutilities:1
# conceptual:1
# itunesconnect_guide:1
# _addingnewapps:1
# addingnewapps:1
# html:68
# enhance:11
# submissions:7
# tracked:3
# tfs:4
# git:5
# optionally:8
# selection:27
# intended:8
# target:32
# download:92
# starter:2
# basic:20
# placeholder:1
# filenames:1
# tweak:1
# modify:18
# submit:37
# in___:2
# complaint:3
# unequal:3
# treatment:1
# dpe:1
# east:1
# alot:4
# favoritism:1
# regards:14
# immediately:23
# judging:1
# friendship:1
# merits:1
# rather:55
# nepotistic:1
# behalf:2
# faith:3
# kindly:3
# urge:1
# look:52
# advance:11
# preferred:11
# manual:12
# complete:16
# inside:57
# hosting:4
# webpage:6
# downloading:16
# browser:101
# instance:43
# hyperlinked:1
# skype:11
# website:37
# flagged:1
# deleted:17
# todays:1
# criminal:1
# government:2
# spy:1
# flagging:1
# secure:12
# prying:1
# eyes:2
# erase:1
# overwriting:2
# bits:1
# garbage:5
# catalog:4
# erasure:2
# policy:12
# enforce:2
# hey:8
# songcollection:6
# playlists:6
# immutable:2
# unabstract:1
# impossible:38
# playlist:12
# transferring:3
# songs:10
# iso:12
# collections:5
# mediaplayer:22
# coll:1
# effectively:3
# agent:5
# contactpicker:3
# desiredfieldswithcontactfieldtype:2
# contactfieldtype:2
# ilist:2
# pickcontactsasync:2
# count:12
# foreach:2
# popups:4
# messagedialog:9
# showasync:16
# contents:15
# fields:21
# smartphone:7
# crash:42
# deploy:21
# visual:59
# studio:55
# entering:10
# front:13
# dialler:3
# task:60
# results:51
# codes:14
# keypad:2
# gsm:3
# conditional:3
# forwarding:5
# approach:11
# alarm:20
# manager:23
# stick:6
# sliverlight:1
# implemented:30
# interesting:12
# move:28
# though:42
# hate:1
# volume:32
# hear:18
# ring:14
# forget:8
# gridviews:1
# boolean:11
# adaptitemheight:3
# integer:1
# maxnumberofcolumns:1
# height:28
# gridviewitems:1
# variable:5
# maxnumberofcolums:2
# columns:8
# especially:50
# usefull:7
# surprise:5
# action:20
# double:10
# news:39
# short:24
# extract:6
# rich:8
# gesture:13
# side:46
# edge:38
# running:79
# customizable:6
# openable:1
# unrolling:1
# notif:1
# form:32
# comfortable:2
# entire:31
# debug:34
# hybrid:4
# webapps:1
# webview:49
# dom:9
# whats:1
# desktopbrowser:1
# safari:23
# voor:1
# webdevelopers:2
# cross:16
# inspect:7
# improved:10
# greatly:8
# console:6
# errors:18
# timeline:6
# css:8
# javascript:28
# angular:5
# node:8
# jquery:3
# popular:27
# and___:4
# transferred:9
# retaining:1
# ratings:36
# eligible:3
# iaps:12
# completely:28
# iap:15
# transfer:36
# grows:5
# unfortunate:2
# reasons:18
# ownership:1
# ideally:12
# intact:2
# logistically:1
# imagine:15
# nightmare:2
# transferable:1
# do___:2
# copyfolderasync:1
# non:32
# aeb:2
# snippet:2
# storagefoldercopyfolder:1
# firmware:2
# revision:2
# radio:18
# chip:3
# soc:1
# emails:19
# pulled:3
# nature:3
# amreading:1
# corespondence:1
# mailbox:2
# approx:3
# seconds:26
# ideas:15
# dejan:1
# apply:15
# policies:12
# credibility:1
# lost:23
# applying:1
# stuff:23
# failing:7
# worth:6
# exactly:16
# went:11
# benefit:10
# confused:5
# couple:12
# anyway:20
# thru:1
# spending:4
# responsible:4
# pointing:7
# talks:3
# firm:1
# independent:9
# helper:5
# more___:1
# calculator:4
# copy:38
# paste:23
# numbers:21
# tab:35
# figures:4
# copying:5
# import:14
# documents:10
# convinient:2
# copyandreplaceasync:1
# copyasync:1
# namely:1
# chaining:2
# operations:13
# submitting:12
# grounds:1
# mistakes:1
# manifest:22
# populate:5
# corresponding:6
# giving:22
# chance:10
# mismatch:1
# terrible:8
# yard:1
# standing:3
# outside:28
# wall:3
# router:1
# large:34
# interactive:4
# prev:2
# colorful:1
# sort:25
# panel:17
# vote:14
# some___:1
# attached:20
# small:49
# depending:8
# included:25
# attachement:2
# dialogue:2
# higher:6
# talk:5
# someone:32
# resolve:14
# kind:40
# misunderstanding:1
# refuse:1
# communication:23
# stops:7
# unbelievably:1
# azure:13
# officer:1
# escalation:1
# leave:26
# sub:6
# pair:7
# refusing:1
# adequate:1
# strike:1
# publisher:20
# improvements:8
# users___:1
# instagram:5
# vimeo:3
# goals:2
# week:21
# favourites:1
# teams:8
# plays:10
# rock:1
# extreme:4
# pinchin:1
# pinchout:1
# miss:8
# putting:3
# notes:6
# bar:70
# cortina:1
# silence:3
# makes:82
# skip:9
# localizationstring:1
# harness:1
# translator:7
# lazy:1
# translating:2
# local:58
# saving:24
# dictionary:7
# downloads:33
# locality:2
# retrieve:9
# facing:7
# major:4
# ith:1
# second:33
# internal:21
# typed:5
# inactivity:1
# reboot:12
# pulling:2
# clsing:2
# cases:29
# pop:8
# features:75
# terrifying:1
# concern:6
# happen:23
# cause:24
# phenomenon:1
# code___:2
# restricted:8
# flexible:5
# whatsapp:3
# audios:1
# truecaller:2
# interpret:1
# numerous:1
# corporate:16
# casual:3
# variants:1
# boot:10
# fresh:4
# restarted:4
# msg:2
# mapelement:2
# derived:3
# mappolygon:5
# arguments:11
# identification:3
# backing:2
# objects:42
# sealed:3
# locker:1
# locks:2
# enough:22
# specify:28
# spam:7
# alerts:5
# middle:5
# extremely:25
# symbian:3
# opportunity:5
# period:10
# geolocator:8
# unreliable:3
# confidence:3
# encountered:6
# positionchanged:2
# reportinterval:3
# ignored:7
# simulator:4
# reasonable:5
# job:11
# honouring:1
# interval:8
# seem:36
# ignore:8
# regularly:7
# take:90
# expect:18
# honoured:1
# degree:2
# accuracy:4
# accurate:8
# getpositionasync:1
# getgeopositionasync:2
# timespan:2
# stop:26
# despite:6
# timeout:12
# parameter:13
# general:18
# poorly:4
# changing:24
# active:14
# gelocator:1
# exceptions:9
# requires:37
# magical:2
# undocumented:7
# attaching:5
# handlers:7
# implicit:5
# deliberate:1
# does___:1
# hung:3
# generating:8
# online:30
# sorting:10
# abilities:2
# title:60
# acsending:1
# creationtimestamp:1
# acesending:1
# sorted:7
# creation:20
# timestamp:9
# updated:47
# ascending:3
# descending:2
# forcing:8
# upgraded:7
# behave:7
# differently:5
# massive:3
# headaches:3
# pleas:3
# wmappmanifest:3
# box:35
# legacy:4
# jump:8
# jumping:4
# unnecessary:9
# actions:8
# expand:19
# comparable:3
# triggered:11
# holding:5
# standard:60
# combination:4
# logical:1
# sounds:10
# processing:25
# firefox:22
# worked:14
# late:5
# sharpdx:4
# codebehind:1
# path:49
# throws:11
# unable:21
# invoice:13
# incredibly:4
# unpopular:1
# accountant:1
# snail:1
# invoices:2
# leading:1
# technology:11
# business:40
# flashsms:1
# blocked:7
# unanswered:2
# somewhere:14
# creates:11
# resized:7
# smaller:13
# uploads:7
# cloud:26
# finds:4
# deletes:4
# lets:19
# assume:16
# stolen:1
# password:49
# thief:2
# stays:5
# resize:4
# police:1
# cloud___:1
# located:5
# memory:41
# signal:16
# reception:2
# uncut:1
# sometime:1
# city:3
# often:34
# loses:2
# strong:14
# going___:1
# hope:45
# tiles___:1
# wonder:4
# switches:3
# oldest:3
# ones:29
# closed:20
# menues:1
# denies:1
# pin:26
# corporation:2
# appreciate:11
# pull:13
# specified:14
# keyword:11
# descriptive:2
# overlays:3
# screenshot:18
# sensitive:12
# fullscreen:11
# stardock:1
# deskscapes:1
# trick:2
# notice:15
# easiest:3
# waterfall:1
# bet:2
# spinning:3
# earth:8
# wind:1
# blowing:1
# river:1
# streaming:10
# waterfalls:1
# anyone:13
# knowing:2
# freezing:1
# helpful:34
# reminder:27
# starts:16
# ends:6
# month:10
# reminds:2
# tue:1
# render:10
# pdf:33
# link:80
# github:46
# mishauliutin:1
# mupdf:1
# config:5
# restarts:3
# aplicaci__n:1
# oficial:1
# telegram:1
# que:7
# existe:1
# para:2
# una:11
# esta:2
# comenzando:1
# utilizar:3
# mucho:1
# tuviera:1
# oferta:1
# aplicaciones:4
# mensajer__a:1
# herramientas:1
# tan:1
# amplia:1
# como:5
# los:2
# dem__s:1
# seguramente:1
# seria:2
# buena:2
# competencia:1
# mayor__a:1
# las:2
# est__n:1
# ingles:1
# muchas:1
# limitan:1
# sus:1
# capacidades:1
# wireless:8
# ways:23
# auditing:1
# wpcentral:1
# analyzer:2
# schedule:10
# reviews:69
# countrys:2
# review:48
# germany:7
# switzerland:1
# austria:3
# rating:31
# stars:8
# usa:6
# star:15
# france:4
# total:25
# equal:5
# of___:1
# resets:3
# difficult:26
# determine:9
# favorite:7
# favorites:9
# knownfolders:3
# cameraroll:3
# mark:15
# celebrate:1
# photochoosertask:3
# chosen:5
# cropping:4
# tool:50
# outstanding:1
# photocroptask:2
# byte:5
# optional:15
# parameters:19
# ratio:4
# aplication:4
# space:38
# order:50
# brand:3
# htc:12
# samsung:5
# considerations:3
# schedulednotification:1
# recurrencetype:2
# beyond:17
# daily:7
# weekly:6
# monthly:2
# endofmonth:1
# yearly:1
# weeks:16
# quarter:1
# frequency:6
# cursor:10
# finger:14
# organized:2
# storing:5
# agree:3
# dpf:1
# environment:29
# remote:35
# potential:11
# scenarios:30
# slat:4
# virtual:31
# hyper:25
# parallels:4
# child:2
# physical:8
# host:11
# fully___:1
# cool:18
# applicationbar:9
# navigational:1
# combine:1
# skds:1
# sdks:5
# reduce:15
# misunderstandings:1
# compatible:12
# filesystem:4
# particular:11
# accessing:12
# xna:9
# par:6
# mixing:7
# mic:4
# loyal:1
# fans:2
# frustrated:3
# feature___:2
# translate:9
# lastplayeddate:2
# addeddate:2
# optimize:3
# filters:8
# introduce:9
# unsafe:3
# shared:16
# performance:39
# author:8
# bepuphysics:1
# simulation:2
# worlds:1
# goal:7
# optimal:1
# maintain:11
# codebases:1
# bunch:6
# queries:6
# structures:3
# hand:16
# suboptimal:1
# lowest:2
# denominator:1
# crippling:1
# competing:2
# motivations:1
# resulted:3
# codebase:2
# harder:6
# yet:34
# sufficiently:1
# grained:2
# dropping:9
# repeatedly:3
# horribly:2
# messy:7
# worst:5
# slower:10
# address:28
# justify:1
# expense:3
# fallbacks:1
# kept:8
# enabling:10
# implementations:5
# resource:20
# constrained:2
# busy:8
# cortano:1
# anything:28
# fiddle:1
# profitable:2
# compromise:1
# portal:26
# exported:4
# excel:9
# graph:10
# plotted:2
# quickly:19
# purchase___:1
# genre:5
# section:30
# fall:24
# listed:18
# chinese:12
# keeps:12
# crashing:4
# restarting:5
# wake:9
# exact:11
# timer:11
# improvement:5
# timetrigger:5
# alarmapplicationmanager:1
# triggers:11
# rss:58
# infinite:11
# scrolling:34
# scrolls:6
# forgotten:2
# quiet:4
# hours:24
# disruptive:1
# meeting:3
# inner:4
# circle:1
# vibrate:16
# says:13
# alert:7
# podcast:18
# bookmark:7
# away:21
# bookmarks:7
# podcasts:7
# persistent:5
# scan:12
# poster:3
# associated:7
# uri:37
# bkmk_uriassociations:1
# direction:16
# navigation:30
# compete:6
# liking:4
# ago:16
# gps:25
# processed:3
# directions:2
# transit:1
# walk:3
# amounts:5
# lengthy:1
# portion:9
# manage:43
# deleting:9
# unwanted:5
# forwarded:1
# near:16
# configured:7
# cod:1
# nofificaiones:1
# moved:15
# meego:1
# guy:1
# cleaner:2
# copied:8
# introduced:12
# family:6
# shot:11
# coudn:1
# unusable:4
# ____________:17
# _____________________________________________________________________________________________________________________________________________:1
# __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________:1
# _______________________________________________________________________________________________________________________________________________________________________________________:1
# pocket:35
# offline:13
# viewing:10
# children:6
# handle:35
# statistics:4
# practically:5
# useless:28
# known:14
# reserved:13
# associations:2
# ship:7
# essential:10
# presently:6
# stymied:1
# restriction:9
# limitation:22
# basically:13
# aside:3
# somewhat:5
# draconian:1
# disallow:3
# looking:38
# man:1
# remind:4
# read___:1
# ssl:10
# tls:2
# socket:13
# component:18
# pinning:8
# created:43
# chain:15
# individual:14
# stackoverflow:11
# questions:13
# stuck:10
# development:43
# restricting:1
# clients:16
# appliances:1
# manufacturing:1
# insist:1
# regular:16
# verge:3
# suggest:37
# battery:31
# consumption:4
# generation:5
# asked:15
# dir:3
# opposite:4
# greater:10
# processes:5
# corrupted:2
# setup:11
# wizard:7
# finished:6
# hidden:14
# excellent:13
# monitor:9
# lack:13
# raw:5
# listen:10
# incomming:3
# connections:11
# paired:2
# bluetooth:31
# smart:16
# watch:14
# disconnected:2
# timed:2
# presses:3
# handles:8
# involved:2
# trigger:18
# listening:8
# spp:1
# drain:3
# comming:1
# accessories:3
# compile:16
# shaders:2
# runtime:27
# huge:15
# inconvenience:1
# angle:3
# producing:1
# compliant:4
# opengl:2
# port:28
# strength:4
# distance:3
# positioning:2
# aera:1
# ibeacon:1
# recieve:1
# scheduled:6
# meetings:1
# linked:4
# yahoo:3
# instances:6
# audiovideocapturedevice:2
# dispose:4
# deactivated:2
# disposal:2
# situations:10
# activatedeventargsisapplicationinstancepreserved:1
# magically:3
# disposed:1
# detect:15
# deeply:2
# embedded:18
# tour:1
# poor:14
# synchronising:1
# words:19
# sucks:3
# nabto:1
# iinternetprotocol:1
# interfaces:10
# protocol:14
# registry:4
# batterymanager:1
# mechanism:12
# plugged:11
# tells:3
# batterysource:3
# deadlines:1
# fulfill:2
# handy:7
# progressbar:2
# indicating:1
# steps:12
# certified:5
# pending:4
# taking:14
# progress:20
# waiting:14
# smartcard:10
# communicate:8
# smartcards:1
# public:37
# transport:19
# decided:7
# browsing:14
# united:5
# states:17
# potentially:11
# enjoying:2
# suggesting:3
# consumer:7
# asides:1
# wonderful:4
# toggle:12
# bother:2
# promotion:2
# arsenal:1
# seller:2
# ads:13
# instagrams:1
# depend:7
# fair:4
# voting:2
# the___:5
# partially:5
# reduces:3
# transparency:6
# verify:12
# transaction:8
# interacted:4
# pressing:9
# logo:6
# touched:2
# implied:1
# cas:1
# costatemete:1
# presents:4
# member:6
# main:28
# identify:5
# prepare:2
# sensors:6
# standby:1
# blackberry:7
# apk:1
# conjunction:4
# xamarin:20
# hire:3
# hardly:4
# focus:39
# captured:4
# suppose:9
# forex:1
# trading:1
# bounce:2
# webbrowser:5
# cheap:5
# bounds:4
# elastic:1
# lightbox:1
# littlewoods:1
# cluttering:1
# defaults:2
# equipment:2
# keyboards:4
# everyone:12
# save:93
# spent:7
# answers:9
# suggestion:41
# declined:1
# taps:3
# unlocks:2
# tapping:11
# unlocking:2
# unlocked:5
# pops:7
# definitely:7
# snooze:1
# navigationuri:1
# obsolete:3
# limitations:13
# furthermore:9
# scientific:1
# proofs:1
# reminders:2
# arrive:3
# fraction:1
# reminder___:1
# kill:4
# ram:3
# mhz:1
# paging:2
# rom:1
# typing:13
# ______:10
# unresponsive:3
# along:14
# shut:6
# responsive:4
# months:16
# submissioned:2
# unzip:7
# test:81
# hanging:6
# indent:2
# paragraph:3
# lacks:11
# textindent:1
# hacking:1
# bulleting:1
# build:109
# bullets:6
# numbering:3
# numberstart:1
# int:12
# inherit:5
# numberstyle:2
# enum:6
# bullet:1
# letter:8
# roman:1
# numberflags:1
# flags:2
# uppercase:2
# dottedlevels:1
# numberlevel:1
# enroll:6
# musician:1
# mails:3
# versioning:1
# winphone:1
# area:45
# winpho:4
# brings:7
# opinion:12
# stills:1
# contribute:4
# vanguardist:1
# thank:19
# webcams:1
# emulation:1
# range:8
# addition:28
# wxga:11
# scalings:1
# login:38
# usability:3
# boring:3
# photosynth:1
# specifically:15
# chicken:1
# egg:1
# circumvented:1
# somehow:11
# charts:5
# listing:22
# anywhere:12
# distribution:8
# randomized:2
# highly:11
# rated:7
# frequently:10
# dwindles:2
# fairly:7
# reviewed:2
# subject:13
# variety:5
# opinions:3
# decent:4
# exposure:6
# featured:9
# ten:2
# random:8
# viewed:6
# considerable:1
# amount:29
# rough:1
# beginning:4
# mend:1
# flaws:1
# successful:9
# cents:1
# less___:1
# tones:1
# hide:17
# cprog:1
# exe:20
# ground:5
# baml:1
# dissatisfied:1
# refund:2
# customer:18
# paid:19
# disliked:2
# wanted:15
# examine:1
# filtered:3
# subset:2
# familiar:4
# exposed:8
# anniversary:10
# showcontacttask:2
# shortcut:20
# twitter:51
# networking:8
# especially___:1
# ocr:7
# hawaii:2
# techniques:1
# libraries:19
# clicked:8
# alias:1
# thinking:7
# meant:6
# changed:35
# slightly:8
# aliases:1
# preferable:1
# certificatio:1
# nprocess:1
# only___:1
# mass:3
# multimedia:1
# visible:44
# cable:9
# liked:8
# microsd:2
# copyright:1
# schouldn:1
# java:14
# inaccessible:2
# reflection:2
# trust:10
# levels:9
# unique:9
# appointment:6
# differentiate:2
# entities:3
# identifier:1
# listbox:8
# elements:28
# sizes:9
# scrollintoview:2
# scrollviewer:15
# position:40
# rectangles:1
# resolutions:7
# scale:13
# wvga:6
# languages:31
# reloads:2
# ask:27
# produce:9
# inherits:2
# togglebutton:2
# filenotfoundexception:2
# thrown:7
# output:25
# nicksnettravels:1
# builttoroam:1
# unpaired:2
# peerfinder:1
# alternateidentities:1
# gapless:1
# playback:17
# album:6
# pausing:5
# models:7
# learn:14
# aupport:1
# voice:25
# unnstall:1
# muted:1
# displays:15
# phonefontfamilysemibold:1
# phonefontsizemedium:1
# phonetextnormalstyle:1
# weight:3
# medium:2
# sized:3
# semibold:2
# encourage:3
# consistency:7
# phonetextnormal:1
# pivot___:1
# haciendo:1
# celular:2
# del:2
# pueda:1
# almacenamiento:1
# masivo:1
# cualquier:1
# otro:1
# devicestatus:1
# manufacturer:4
# accesible:1
# round:4
# managed:16
# equivalent:10
# protected:2
# auth:9
# fires:6
# navigating:8
# navigated:5
# credential:2
# showed:4
# reload:4
# tone:2
# txt:6
# thankful:1
# arrow:5
# room:5
# homescreen:3
# wasteful:1
# rid:9
# fit:9
# cameracapturetask:2
# roll:8
# clothes:2
# shopping:3
# buy:22
# webclient:2
# cookies:13
# credentials:20
# indirect:1
# browserhttp:1
# kinda:4
# buggy:4
# leak:9
# medialibrary:10
# savevideo:1
# uncomfortable:1
# gode:1
# toas:1
# voltage:2
# utilizing:3
# induction:3
# charger:3
# inductive:2
# charging:6
# chargers:1
# thick:1
# centering:1
# plate:1
# reduced:3
# capacity:4
# visbility:1
# mah:3
# health:5
# comparisons:3
# inneficiency:1
# time___:1
# highest:2
# throuth:1
# morning:5
# repeat:4
# backgroundtransferrequest:1
# beneficial:8
# majority:5
# overall:4
# negative:6
# wise:5
# reward:2
# carefully:1
# abuses:1
# indication:3
# prior:8
# indicate:10
# slide:5
# fixes:4
# cut:7
# strongly:3
# green:6
# accent:9
# colors:11
# glass:3
# zune:24
# customization:9
# scroller:1
# linkedin:4
# said:17
# landscape:2
# covered:6
# shortens:2
# interfere:1
# teethering:1
# stuff___:1
# conferencing:1
# sec:6
# subscribed:8
# statuschanged:1
# snap:2
# cripples:1
# deletion:3
# angry:2
# mouse:42
# owa:1
# definitions:4
# activesync:1
# seriously:7
# designated:2
# knows:9
# reasoning:3
# mailboxes:1
# enumerate:3
# unread:15
# medical:1
# proximity:4
# watches:2
# apliances:1
# cars:2
# innumerable:1
# industrial:3
# pen:8
# door:1
# usual:2
# expression:6
# encoder:3
# feeds:67
# element:37
# src:4
# mlmidev:1
# webcastcenter:1
# mlm:1
# idev:1
# isml:1
# aapl:1
# computers:10
# wonderfully:2
# bitgravity:1
# recommend:8
# recommend___:1
# retweet:1
# answer:13
# tweets:8
# rediculous:1
# rigid:1
# functional:3
# utilitap:1
# icalendar:1
# aslong:1
# lacking:10
# turned:7
# jan:2
# responsiveness:4
# worse:11
# jumps:5
# undo:3
# patch:1
# dialog:41
# map:61
# route:18
# street:7
# stay:10
# maproute:2
# accepts:5
# constructor:5
# routequery:2
# traveled:2
# jogging:1
# mappolyline:8
# polyline:1
# centered:5
# implements:1
# iroutepath:2
# accept:12
# inteface:1
# at___:1
# continues:4
# grow:4
# till:7
# uninstalling:1
# replaces:2
# messenger:5
# base:23
# assistant:1
# movie:3
# nearest:4
# theatres:1
# shoe:1
# stock:5
# netherlands:1
# metadata:13
# artist:12
# india:5
# wallpaper:5
# emulate:8
# multitouch:2
# exploiting:1
# wheel:3
# stucked:1
# ratios:3
# scaling:7
# scalefactor:1
# giant:1
# pita:1
# uploading:11
# turns:5
# nuts:2
# guys:19
# employed:2
# module:4
# imageresizing:2
# clusters:4
# autoscaling:1
# handler:15
# effort:15
# presentation:5
# projector:1
# valid:8
# registration:34
# pesky:1
# synchronization:3
# synchronized:1
# arrival:2
# downloadprogress:1
# metrotube:1
# tube:1
# pro:45
# seek:4
# trouble:5
# loop:12
# buffering:156
# disappeared:3
# circumstance:1
# seeking:2
# comparison:6
# dinh:1
# a___:3
# xffffffff:1
# executing:1
# fluently:2
# flowing:1
# weed:1
# strain:2
# adress:1
# kontakts:1
# association:6
# utorrentideas:1
# torrent:3
# exploit:3
# drawingsurfaces:1
# _not_:1
# acceptable:6
# proves:2
# technologies:6
# csharp:3
# instantiate:3
# itemcontrol:2
# phonetoolkit:1
# polygons:1
# artistic:1
# gifted:1
# friends:15
# stylish:1
# sad:2
# draw:20
# lat:1
# coordinates:5
# drawn:2
# maplayer:5
# ais_a_layer:2
# opacity:10
# mapitemscontrol:10
# a_tracks:2
# ais_a:3
# stroke:5
# strokethickness:3
# ais_track:1
# a_symbols:1
# canvas:12
# mmsi:1
# canvas_tap_a:1
# polygon:4
# orange:1
# rendertransform:2
# rotatetransform:2
# cog:1
# centerx:1
# centery:1
# map_view:1
# ship_name_visible:1
# binding___:1
# hello:26
# sir:3
# misuse:2
# sufficient:5
# knowledge:12
# mistake:3
# corrupt:2
# wan:7
# na:6
# heart:3
# illegally:1
# engine:8
# plz:6
# millions:4
# decision:3
# favor:1
# capitalising:1
# corrects:1
# apostrophe:1
# comma:1
# lastly:2
# hitting:2
# twice:7
# lower:8
# subsequently:1
# recognise:1
# sentence:2
# spaces:3
# it___:2
# freedom:4
# saw:9
# filled:3
# pinned:6
# accidentally:4
# offer:17
# cancel:14
# connectionsettingstask:1
# permit:5
# partiendo:1
# nada:1
# conectar:1
# con:4
# todo:3
# hotmail:2
# trusted:10
# permissions:5
# agrees:1
# myownemailclient:1
# intervention:2
# toolkit:25
# biometric:4
# supply:2
# facial:2
# recognition:14
# areas:4
# rebind:1
# serach:1
# russia:2
# register:22
# clicks:9
# mydomain:1
# redirected:3
# smilies:1
# colon:2
# dash:1
# parentheses:1
# signs:2
# retreive:1
# tower:2
# informations:2
# mnc:1
# mcc:2
# lac:1
# imei:2
# imsi:1
# scheduler:2
# limiting:7
# extended:11
# desired:3
# loading:35
# indicator:5
# jerky:1
# develope:1
# usd:5
# consistently:3
# physically:1
# capture:15
# represents:6
# gameplay:4
# controlled:2
# accelerometer:2
# rapid:2
# capturing:4
# lucky:1
# character:16
# dies:1
# straight:9
# nowhere:3
# occurring:2
# endroid:1
# computing:2
# advertising:10
# pitorque:1
# mistergoodcat:1
# somethings:1
# offering:4
# two___:1
# heaps:2
# make___:1
# step:14
# semi:5
# entend:1
# ping:5
# tracert:1
# utilities:6
# inclined:1
# inbox:5
# abused:2
# mango:12
# specially:8
# crafted:1
# automate:8
# srvice:1
# smscomposetask:6
# mysms:4
# thesmstextcodemsg:1
# thesmsservicenumber:1
# confirm:4
# sends:8
# response:20
# hanle:1
# rebrand:1
# purchaser:1
# competition:4
# concerned:7
# pushing:1
# selling:6
# acknowledge:1
# risk:8
# losing:7
# gaining:2
# containing:6
# worrying:1
# exiting:2
# label:5
# instructing:1
# resetting:2
# selectionchanged:3
# behaved:1
# mouseleftbuttonup:1
# activate:8
# dragging:11
# lifting:2
# loved:2
# panned:1
# book:13
# caller:6
# reported:9
# concerns:3
# regarding:9
# impact:11
# decisions:1
# topic:4
# opt:10
# drm:1
# programmatically:14
# various:16
# shots:2
# restrict:2
# deploying:1
# faster:18
# computer:23
# originally:3
# sergiy:2
# characters:23
# question:26
# marks:8
# gmail:13
# ________:16
# brolen:1
# layout:14
# _broken_:1
# headers:33
# considering:14
# spotted:2
# pic:5
# tweet:7
# keyboard___:1
# older:15
# _________marketplace___apphub__________________________________________________________________________________________________________________:1
# ___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________:1
# ____:4
# ______________________________________________________________________________________________________________________________app:1
# hub___marketplace___________________________________________________:1
# geotrust:1
# claimed:1
# indeed:2
# discouraged:1
# binded:1
# carousel:3
# bingmapsdirectionstask:2
# prompt:9
# match:9
# design:42
# configure:8
# integrated:10
# digitally:1
# signing:2
# facilidade:1
# definir:2
# qualquer:1
# toque:1
# transfer__ncia:1
# arquivos:1
# sem:2
# necessidade:1
# pois:1
# rid__culo:1
# ter:1
# programa:1
# ruim:1
# poder:3
# coisas:1
# maneira:1
# quero:1
# tramp:1
# alarms:2
# facility:2
# ridiculous:16
# damn:2
# wife:2
# vagina:1
# research:4
# newlines:2
# descriptions:14
# microsoft___:1
# flash:14
# configurable:9
# deep:11
# came:5
# talking:8
# meetups:1
# largest:1
# vector:4
# creative:5
# commons:2
# pack:5
# creating___:1
# stocks:1
# constantly:8
# proving:1
# authentication:15
# temporary:3
# grantaccountaccesstask:1
# providers:5
# tidy:1
# relatively:5
# alphabetized:1
# cumbersome:3
# adjustment:8
# brightness:10
# compensation:1
# increases:5
# decreases:2
# context:31
# interoperability:1
# guide:1
# wondering:3
# buttom:1
# print:17
# driven:2
# gear:1
# ipads:1
# dissappointing:1
# beeing:1
# contemplations:1
# these___:1
# vez:2
# quiten:1
# interfaz:1
# metro:6
# bien:1
# desde:1
# escritorio:1
# pero:1
# m__vil:1
# horrible:3
# experienced:4
# restarurant:1
# wherever:2
# initiated:2
# vibration:2
# displaying:16
# align:11
# doctype:3
# head:10
# charset:2
# utf:2
# div:19
# solid:3
# __________________:3
# __________:7
# padding:4
# ________________________:10
# ______________:3
# incorrectly:1
# trophy:1
# div___:1
# bedside:1
# touching:3
# pinch:6
# lighter:3
# darker:1
# colours:2
# alpha:8
# graphics:14
# validatesonexceptions:1
# documented:6
# textbox:41
# experiences:7
# hubs:3
# designers:3
# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer
filtered_sentence=TreebankWordDetokenizer().detokenize(filtered_sentence)
filtered_sentence
# Out:
# 'please enable removing language code dev center language history example ever selected laguages published xap store causes tile localization show default tile localization bad note csproj file supportedcultures entry like supportedcultures supportedcultures removed language code published new xap version old xap version still remains store replaced unpublished wich means new version fully replaced old version causes serious problems users still receive old xap version app store randomly gives old xap new xap version app app version version xap submission xap works xap works sometimes store gives wrong xap version app windows phone users option remove language code app language history option completly replace fully replace prevoius xap currently ever mistakenly selected language bad situation forever live wrong tile displayed russian language store english one publish update removed language update fully replace old version truble store randomly deliver old wrong version xap write lot support ticket one really cares issue engineering team solve issue one following provide workaround removing language language history need culture way remove language history ever posted app language support add implement appreslib dll xxxx mui language culture documentation appreslib dll xxxx mui exist culture http msdn microsoft com library windowsphone develop aspx thanks tom please enable removing language code dev center language history example ever selected laguages published xap store causes tile localization show default tile localization bad wich means new version fully replaced old version causes serious___ driving car need make call times phone use vocal commands starting bing search instead call contact press power button unlock device open phone say call person name device start calling correctly driving mode activated also italian translation reading sms device say fatto ending operation work say finito say fatto vocal command unrecognized little bugs lumia first upgrade work fine vocal commands first upgrade bad recognize commands old work fine using sony car stereo little bugs lumia first upgrade work fine vocal commands from___ outlook color schemes settings current live tile size open network settings tap call settings hit power button sleep mode wait minutes switch mobile window blank heading reproducible lumia cyan update always use feature please fix asap seems issue card preview getting annoying please fix working lob field engineering civil structural point make app universal across devices engineers spend much time learning relearning controls app runs tablets engineers work field come back office continue working data windows windows phone universal app hoping adapt app windows phone well saved live data saved onedrive allow roaming devices found windows phone file picker access onedrive futureaccesslist aspect alone prevents adaptation app windows phone platform please allow windows phone file folder picker access onedrive store location futureaccesslist also please allow onedrive folder stored locally like winrt otherwise real universal app saved live data are___ far tried three different apps access pre windows phone photos needs fixing number priority would nice give developers option put payment hold reach appropriate threshold option put top next due payment reach threshold dev preview theres bug push service i__m mobile data connection get notifications i__m wifi connection push server found workaround turn mobile data connection manually push wifi works gdr system recognized automaticly wich connection i__m using turn push service automaticly cellular wifi everytime works dev preview doesn__t try insert new bank account receive error validation bank account country account think correct using paypal receive money another country want pay extra costs paypal also insert tax plan country different country account please remove validation validate according tax plan country account another post voted change country ...

# %% [markdown]
# # Creating WordCloud

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(filtered_sentence)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # Creating FreqDist Graph

# %%
import nltk
import seaborn as sns
a = nltk.FreqDist(filtered_sentence.split())
d = pd.DataFrame({'Word': list(a.keys()),
                  'Count': list(a.values())})

d = d.nlargest(columns="Count", n = 20) 
plt.figure(figsize=(16,5))
ax = sns.barplot(data=d, x= "Word", y = "Count")
ax.set_xticklabels(d["Word"], rotation=40, ha="right")
ax.set(ylabel = 'Count')
plt.show()

# %% [markdown]
# # Creating Sparse Matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
df = combDf[combDf["label"].isin([0,1])]
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=3000, stop_words='english')
bow = tfidf_vectorizer.fit_transform(df['new'])
print(df.shape)
print(bow.shape)
df.head()
# Out:
# (8500, 4)
# (8500, 3000)
#       id                                           sentence  label  \
# 0  663_3  "please enable removing language code from the...    1.0
# 1  663_4  "note: in your .csproj file, there is a suppor...    0.0
# 2  664_1  "wich means the new version not fully replaced...    0.0
# 3  664_2  "some of my users will still receive the old x...    0.0
# 4  664_3  "the store randomly gives the old xap or the n...    0.0
#
#                                                  new
# 0   please enable removing language code from the...
# 1   note   your csproj file there     supportedcu...
# 2   wich means the new version not fully replaced...
# 3   some     users will still receive the old xap...
# 4   the store randomly gives the old xap   the ne...

# %% [markdown]
# # Creating Baseline model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
X = bow
y = df["label"]

# %%
model = XGBClassifier()
n_estimators = [int(x) for x in np.linspace(start=1, stop=200, num = 4)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(1, 50, num = 11)]
max_depth.append(None)
min_samples_split = [2, 3, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'eta': [x for x in np.linspace(start=0.01, stop=0.2, num = 4)],
               'min_child_weight ': [int(x) for x in np.linspace(start=1, stop=11, num = 4)],
               'max_depth ': [int(x) for x in np.linspace(start=3, stop=10, num = 4)],
               'gamma': [int(x) for x in np.linspace(start=0, stop=10, num = 4)],
               'subsample': [x for x in np.linspace(start=0.5, stop=1, num = 4)]}
rf_random = RandomizedSearchCV(estimator = model, param_distributions = random_grid, cv = 3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
rf_random.fit(X_train, y_train)
rf_random.best_params_
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# {'subsample': 0.5,
#  'min_child_weight ': 4,
#  'max_depth ': 5,
#  'gamma': 0,
#  'eta': 0.1366666666666667}

# %%
model = XGBClassifier(**rf_random.best_params_)
model.fit(X_train, y_train)
print(model.score(X_test,y_test))
yp = model.predict(X_test)
yp = model.predict(X_test)
cm = confusion_matrix(yp, y_test)
y_test[y_test==1].count()
cm
# Out:
# 0.78
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([[1202,  321],
#        [  53,  124]], dtype=int64)

# %% [markdown]
# # Classification based on threshold

# %%
threshold = 0.2
yp2_prob = model.predict_proba(X_test)
yp2 = (yp2_prob [:,1] >= threshold).astype('int')
cm = confusion_matrix(yp2, y_test)
y_test[y_test==1].count()
cm
# Out:
# array([[903, 100],
#        [352, 345]], dtype=int64)

# %%
s1 = "white and black are not same"
s1New = tfidf_vectorizer.transform([s1])
print(s1New.shape)
p = model.predict(s1New)
print(p)
model.predict_proba(s1New)
# Out:
# (1, 3000)
# [0.]
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([[0.8658265 , 0.13417348]], dtype=float32)

# %%
df2=combDf[combDf["label"].isna()]
print(df2.shape)
df2.head()
# Out:
# (833, 4)
#         id                                           sentence  label  \
# 8500  9566         this would enable live traffic aware apps.    NaN
# 8501  9569  please try other formatting like bold italics ...    NaN
# 8502  9576  since computers were invented to save time i s...    NaN
# 8503  9577  allow rearranging if the user wants to change ...    NaN
# 8504  9579  add simd instructions for better use of arm ne...    NaN
#
#                                                     new
# 8500         this would enable live traffic aware apps
# 8501  please try other formatting like bold italics ...
# 8502  since computers were invented   save time   su...
# 8503  allow rearranging   the user wants   change them
# 8504  add simd instructions for better use   arm neo...

# %%
bow1 = tfidf_vectorizer.transform(df2["new"])
bow1.shape
# Out:
# (833, 3000)

# %%
a=df2["id"]
b=df2["new"]
yp = model.predict(bow1)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
yp.shape
# Out:
# (1700,)

# %%
sub=pd.DataFrame({
    "Id":a,
    "sentence":b,
    "label":yp
})
sub.to_csv('Submission.csv',index=False,header=False)
