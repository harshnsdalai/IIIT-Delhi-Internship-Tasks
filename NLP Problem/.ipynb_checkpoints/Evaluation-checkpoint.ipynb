# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Reading the Files

# %%
Train=pd.read_csv("V1.4_Training.csv",header=None)
Train.sample(10)
# Out:
#            0                                                  1  2
# 7912    8931  There must be a way to handle this kind of pro...  1
# 3862  0_1766  "Add a drop down menu of the sources with numb...  1
# 5192     101  "I have a bar-code scanner attached to my wind...  0
# 4077  0_1986  "I just click subscribe and they appear in my ...  0
# 749    863_2             "You've forgotten to change that icon"  0
# 4295  919_11  "Please provide us a way via the Dev Center to...  1
# 553    819_2  "When using MapElement derived controls, such ...  0
# 2951   0_509  "To make it possible to actually find an app b...  0
# 7488    1244  Currently Microsoft Store under Windows 10 sho...  0
# 4173  0_2082  "Adobe Acrobat doesn't allow the user to set a...  0

# %%
Test=pd.read_csv("SubtaskA_Trial_Test.csv",header=None)
Test.sample(10)
# Out:
#           0                                                  1  2
# 87    13701  "Or, you could just support the native SDK/Dir...  X
# 545  163410  "It can also bring in whole range of new apps ...  X
# 485   16242  "the mutitasking area should have every app th...  X
# 418   16036  "I'd like to control the priority of this back...  X
# 291   15333                  "Let Live tiles be live, please."  X
# 316   15422  "Now that we have API access to contact inform...  X
# 41    13351  "Provide a single link to retrieve all the app...  X
# 401   15911  "Add a method to run another app passing params."  X
# 535   16335          "I believe scrolling should be improved."  X
# 9     13196  "It would be more natural to allow the physica...  X

# %%
Test.drop(2,axis=1,inplace=True)
Test.sample(10)
# Out:
#          0                                                  1
# 353  15642                            "for gps tracking apps"
# 249  14887  "Maximizing all current main apps would be bet...
# 122  13954  "An automated hub for recently used apps would...
# 556  16355  "A business feature that would be really nice ...
# 355  15671              "WPF7 should have one like this too!"
# 86   13692  "Barring that, at least allow for merged listi...
# 128  14045     "This now requires creating a custom control."
# 219  14523  "Link to sql is not efficient at all, could th...
# 147  14092  "(A third was scrapped because of the inabilit...
# 297  15371  "Please implement this, it is important for me...

# %%
Eval=pd.read_csv("SubtaskA_EvaluationData.csv",header=None)
Eval.sample(6)
# Out:
#         0                                                  1  2
# 200  4317  It has support for Linux and I think Windows s...  X
# 512  5310  We do not use Basic authentication so cannot p...  X
# 303  4811              I do this so I can clear all Cookies.  X
# 433  5115  We have a server / cloud backend as part of ou...  X
# 332  4896  After the anniversary update the store shows d...  X
# 27   9819  Maybe you should think about some way to rewar...  X

# %%
Eval.drop(2,axis=1,inplace=True)
Eval.sample(10)
# Out:
#         0                                                  1
# 473  5209                                 I'd love to do it!
# 502  5285  Wouldn't it be better to Call this Firstrun-Se...
# 713  5922  Currently it's difficult to do some of these t...
# 304  4812  An API that would take 5 minutes for someone t...
# 732  5996             I sincerely hope it makes a difference
# 268  4705  So imagine the app in question was one written...
# 577  5546  And if devs respond to that reviews it will al...
# 783  6159  Example An app that allows users to select a t...
# 779  6154  The strange is that when we open the appbar it...
# 395  5027                         Which is not future-proof.

# %%
Eval.describe(include=['O'])
# Out:
#                                                         1
# count                                                 833
# unique                                                833
# top     Sometimes Compass.GetDefault() returns null an...
# freq                                                    1

# %% [markdown]
# # Join the DataSets

# %%
combDf = Train.append([Eval], ignore_index=True)
combDf.sample(10)
# Out:
#             0                                                  1    2
# 3096    0_666                       "Please modify like this. ""  1.0
# 1825  1679_13  "Something like http://livetiles.co.uk/Beta/De...  0.0
# 2006   1732_1  "Would be nice to mirror phone screen to tv th...  1.0
# 39      671_1  "All the saved and live data are saved on oned...  0.0
# 3889   0_1793  "There is no option to open the link directly ...  0.0
# 8608     3248   The following streams are available on the XBOX:  NaN
# 7381      985  The other developers try to force customers to...  0.0
# 2267   1801_1  "App-specific launchers: instead of opening a ...  0.0
# 2174   1779_4  "People Hub __________________________________...  0.0
# 1134   1274_2  "It has a new feature to add a route that will...  0.0

# %% [markdown]
# # Label the Columns

# %%
combDf.columns=['id','sentence','label']
combDf.sample(10)
# Out:
#            id                                           sentence  label
# 411    791_10  "Please consider adding an option to erase a f...    1.0
# 7236      646  This issue has been many times on stack overfl...    0.0
# 3053    0_621  "Besides making it easier for Android/iOS devs...    0.0
# 5188       91  "Currently it is unavailable in Israel and can...    0.0
# 5742     1695  "While I get crashes by OS (Health page) I nee...    0.0
# 528     814_2  "Add PinchIn and PinchOut events, they are com...    1.0
# 2030  1737_10  "This combined with file drag drop from Window...    0.0
# 5741     1692  "In the Health page of Dev Center analytics cr...    0.0
# 6297     3409                  "I'm talking about this website:"    0.0
# 2298  1809_21  "Please make it quick and simple for us to get...    1.0

# %% [markdown]
# # Checking if their is any missing value

# %%
combDf.describe(include=['O'])
combDf["label"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
combDf.shape
# Out:
# (9333, 3)

# %% [markdown]
# # Conveting the sentence to LowerCase

# %%
combDf["sentence"] = combDf["sentence"].str.lower()
combDf.sample(7)
# Out:
#           id                                           sentence  label
# 5522     977  "issue: i developed a desktop application savi...    0.0
# 3130   0_702  "allow all those folders which are accessible ...    1.0
# 9156    5757  i need it to keep the app title bar background...    NaN
# 6651    4384  "keeping this in mind was thinking of making s...    0.0
# 4569   978_7  "windows should allow additional user accounts...    1.0
# 8647    3796  for example three quick touch strokes to scrol...    NaN
# 3565  0_1468                           "i want to turn it off."    0.0

# %% [markdown]
# # Defining function to remove patterns

# %%
import re
def remove_pat(s1, pat, nstr):
    return re.sub(pat, nstr, s1)

# %% [markdown]
# # Removing special Characters

# %%
combDf["new"] = np.vectorize(remove_pat)(combDf["sentence"], "[^a-zA-Z#_]+", " ")
combDf.sample(5)
# Out:
#           id                                           sentence  label  \
# 8415    2638  it is just few lines of code but useful since ...    0.0
# 7730    7371  allow developers to add suggestions to the use...    1.0
# 5942    2394  "some devices/apps do not have the ability of ...    0.0
# 3538  0_1441  "default tags would also be helpful -- even be...    1.0
# 4428   949_1  "i think the whole system of submitting a idea...    1.0
#
#                                                     new
# 8415  it is just few lines of code but useful since ...
# 7730  allow developers to add suggestions to the use...
# 5942   some devices apps do not have the ability of ...
# 3538   default tags would also be helpful even bette...
# 4428   i think the whole system of submitting a idea...

# %% [markdown]
# #  Removing the words whose length is less than 3

# %%
combDf["new"] = np.vectorize(remove_pat)(combDf["new"], r"\b[a-z]{1,2}\b", " ")
combDf.sample(10)
# Out:
#           id                                           sentence  label  \
# 6406    3678               "is this new policy or is it a bug?"    0.0
# 5854    2107  "i've looked into using a softwarebitmapsource...    0.0
# 3656  0_1560                      "add integration with trello"    1.0
# 9263    6098  if the location is slightly on the right the r...    NaN
# 5013    1575  "that's why i'm suggesting a specialized textb...    1.0
# 8145    1981  if the indexer is really broken (for some reas...    0.0
# 7218     615  its usage would be similar to selectedforegrou...    0.0
# 7129     385  this is the second question with kind of hardw...    0.0
# 4742  1026_2  "note, that if you have a store account, the a...    0.0
# 657    842_2                 "so please consider this request."    0.0
#
#                                                     new
# 6406                       this new policy         bug
# 5854       looked into using   softwarebitmapsource ...
# 3656                       add integration with trello
# 9263    the location   slightly   the right the retu...
# 5013   that   why     suggesting   specialized textb...
# 8145    the indexer   really broken for some reason ...
# 7218  its usage would   similar   selectedforeground...
# 7129  this   the second question with kind   hardwar...
# 4742   note that   you have   store account the apps...
# 657                       please consider this request

# %% [markdown]
# # Combining all sentences

# %%
import matplotlib.pyplot as plt
all_words = ' '.join([text for text in combDf['new']])
all_words
# Out:
# ' please enable removing language code from the dev center language history for example   you ever selected   and     laguages and you published this xap   the store then   causes tile localization   show the     default tile localization which   bad   note   your csproj file there     supportedcultures entry like this supportedcultures           supportedcultures when   removed the   language code and published   new xap version the old xap version still remains   the store with replaced and unpublished   wich means the new version not fully replaced the old version and this causes   very serious problems   some     users will still receive the old xap version     app   the store randomly gives the old xap   the new xap version     app     app has     version and     version xap   the same submission   the   xap works only     and the   xap works only for     sometimes the store gives the wrong   xap version     app   windows phone users     should     option   remove the   language code from   app language history     option   completly replace fully replace the prevoius   xap     currently   you ever mistakenly selected     language than you will       very bad situation forever you can live with the wrong tile displayed for russian language   the store the english one   you can publish   update with the removed   language but this update will not fully replace the old version and you will   truble   the store will randomly deliver the old wrong version   your xap     write   lot support ticket   this but   one really cares   this issue   the engineering team can solve this issue   they   one   the following   provide   workaround for removing the   language from the language history   have   need for   culture just for     but there     way   remove   from the language history   you ever posted your app with   language support     add and implement   appreslib dll xxxx mui for the   language culture   the documentation appreslib dll xxxx mui exist only for     and not for   culture http msdn microsoft com     library windowsphone develop       aspx thanks tom please enable removing language code from the dev center language history for example   you ever selected   and     laguages and you published this xap   the store then   causes tile localization   show the     default tile localization which   bad   wich means the new version not fully replaced the old version and this causes   very serious___ more   when   driving   car and need   make call     times the phone use vocal commands for starting bing search instead   call contact   but     press power button and unlock device and open phone and say call person name device start calling correctly   this   driving mode activated   also   italian translation after reading sms the device say fatto for ending operation but work only     say   finito       say fatto vocal command unrecognized   other little bugs with   lumia before first   upgrade work fine with vocal commands but from first upgrade   now   bad   don   recognize commands   but   old   work fine using same   sony car stereo   other little bugs with   lumia before first   upgrade work fine with vocal commands but from___ more   outlook color schemes   settings current live tile size and more   open the network settings and tap   call settings   hit the power button       sleep mode   wait for minutes and switch   the mobile again   the window will   blank with only heading       reproducible   lumia cyan update     always use this feature please fix asap   seems there     issue with the   card     preview   its getting annoying please fix this       been working     lob for   field   engineering civil structural   the point     make the app universal across devices   that our engineers   not have   spend too much time learning and relearning the controls   and because the same app runs   tablets and     our engineers can work   the field come back   their office and continue working with the same data   their   ...

# %% [markdown]
# # Removing Stop Words

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(all_words) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  
print(filtered_sentence)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     674     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 675     raise LookupError(resource_not_found)
#     676
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - 'C:\\Users\\HP/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\HP\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\HP\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\HP\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\HP\\AppData\\Roaming\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-17-6bd09c49b019> in <module>()
#       2 from nltk.tokenize import word_tokenize
#       3
# ----> 4 stop_words = set(stopwords.words('english'))
#       5
#       6 word_tokens = word_tokenize(all_words)
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     673     sep = '*' * 70
#     674     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 675     raise LookupError(resource_not_found)
#     676
#     677
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - 'C:\\Users\\HP/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\HP\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\HP\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\HP\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\HP\\AppData\\Roaming\\nltk_data'
# **********************************************************************

# %% [markdown]
# # Creating Frequency List

# %%
import nltk
freq = nltk.FreqDist(filtered_sentence) 
for key,val in freq.items(): 
    print (str(key) + ':' + str(val))

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer
filtered_sentence=TreebankWordDetokenizer().detokenize(filtered_sentence)
filtered_sentence

# %% [markdown]
# # Creating WordCloud

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(filtered_sentence)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # Creating FreqDist Graph

# %%
import nltk
import seaborn as sns
a = nltk.FreqDist(filtered_sentence.split())
d = pd.DataFrame({'Word': list(a.keys()),
                  'Count': list(a.values())})

d = d.nlargest(columns="Count", n = 20) 
plt.figure(figsize=(16,5))
ax = sns.barplot(data=d, x= "Word", y = "Count")
ax.set_xticklabels(d["Word"], rotation=40, ha="right")
ax.set(ylabel = 'Count')
plt.show()

# %% [markdown]
# # Creating Sparse Matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
df = combDf[combDf["label"].isin([0,1])]
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=3000, stop_words='english')
bow = tfidf_vectorizer.fit_transform(df['new'])
print(df.shape)
print(bow.shape)
df.head()

# %% [markdown]
# # Creating Baseline model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
X = bow
y = df["label"]

# %%
model = XGBClassifier()
n_estimators = [int(x) for x in np.linspace(start=1, stop=200, num = 4)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(1, 50, num = 11)]
max_depth.append(None)
min_samples_split = [2, 3, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'eta': [x for x in np.linspace(start=0.01, stop=0.2, num = 4)],
               'min_child_weight ': [int(x) for x in np.linspace(start=1, stop=11, num = 4)],
               'max_depth ': [int(x) for x in np.linspace(start=3, stop=10, num = 4)],
               'gamma': [int(x) for x in np.linspace(start=0, stop=10, num = 4)],
               'subsample': [x for x in np.linspace(start=0.5, stop=1, num = 4)]}
rf_random = RandomizedSearchCV(estimator = model, param_distributions = random_grid, cv = 3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
rf_random.fit(X_train, y_train)
rf_random.best_params_

# %%
model = XGBClassifier(**rf_random.best_params_)
model.fit(X_train, y_train)
print(model.score(X_test,y_test))
yp = model.predict(X_test)
yp = model.predict(X_test)
cm = confusion_matrix(yp, y_test)
y_test[y_test==1].count()
cm

# %% [markdown]
# # Classification based on threshold

# %%
threshold = 0.2
yp2_prob = model.predict_proba(X_test)
yp2 = (yp2_prob [:,1] >= threshold).astype('int')
cm = confusion_matrix(yp2, y_test)
y_test[y_test==1].count()
cm

# %%
s1 = "white and black are not same"
s1New = tfidf_vectorizer.transform([s1])
print(s1New.shape)
p = model.predict(s1New)
print(p)
model.predict_proba(s1New)

# %%
df2=combDf[combDf["label"].isna()]
print(df2.shape)
df2.head()

# %%
bow1 = tfidf_vectorizer.transform(df2["new"])
bow1.shape

# %%
a=df2["id"]
b=df2["new"]
yp = model.predict(bow1)

# %%
yp.shape

# %%
sub=pd.DataFrame({
    "Id":a,
    "sentence":b,
    "label":yp
})
sub.to_csv('Submission.csv',index=False,header=False)
