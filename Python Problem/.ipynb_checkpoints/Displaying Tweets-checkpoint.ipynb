# %% [markdown]
# # Python Script for Showing tweets from JSON file in Tabluar Form

# %%
import numpy as np                                                    #for storing data in array
import pandas as pd                                                   #for creating dataframe of tweets
import json                                                           #for common json functionalities

# %% [markdown]
# Function for opening json file

# %%
def json_input(location):
    with open(location) as json_file:  
        data = json.load(json_file)
        return data

# %%
data = json_input("tweets.json")

# %% [markdown]
# Converting Json data to DataFrame

# %%
tweets = pd.DataFrame.from_dict(data)

# %%
(tweets)
# Out:
#                                                 Tweets     created_at  len  \
# 0    RT @Harvard: Professor Jelani Nelson founded A...  1554786267000  136
# 1    RT @emnlp2019: For anyone interested in submit...  1554786251000  140
# 2    RT @multimediaeval: Announcing the 2019 MediaE...  1554752289000  140
# 3    Many Congratulations to @midasIIITD student, S...  1554707292000  140
# 4    @midasIIITD thanks all students who have appea...  1554694062000  140
# 5    @himanchalchandr Meanwhile, complete CV/NLP ta...  1554646649000   55
# 6    @sayangdipto123 Submit as per the guideline ag...  1554646629000   50
# 7    We request all students whose interview are sc...  1554637404000  140
# 8    Other queries: "none of the Tweeter Apis give ...  1554620119000  139
# 9    Other queries: "do we have to make two differe...  1554620018000  140
# 10   Other queries: "If using Twitter api, it does ...  1554615147000  140
# 11   Response to some queries asked by students on ...  1554614980000  140
# 12   RT @kdnuggets: Top 8 #Free Must-Read #Books on...  1554570689000   89
# 13   @nupur_baghel @PennDATS Congratulation @nupur_...  1554569007000  140
# 14   We have emailed the task details to all candid...  1554480517000  140
# 15   RT @rfpvjr: Our NAACL paper on polarization in...  1554437111000  139
# 16   RT @kdnuggets: Effective Transfer Learning For...  1554437083000   98
# 17   RT @stanfordnlp: What’s new in @Stanford CS224...  1554316313000  140
# 18   RT @DeepMindAI: Today we're releasing a large-...  1554311072000  140
# 19   RT @ylecun: Congratulations Jitendra Malik !\n...  1554282220000  113
# 20   RT @IIITDelhi: Another chance to take admissio...  1554277562000  140
# 21   Dear @midasIIITD internship candidates who hav...  1554178813000  140
# 22   Looking forward to your paper submission to @I...  1554173094000  140
# 23   RT @ngrams: Reproducibility in multimedia rese...  1554172544000  140
# 24   Online application for https://t.co/DJFDrQsHZP...  1554101588000  140
# 25   RT @ACMMM19: A final reminder of the Reproduci...  1554027684000  140
# 26   RT @isarth23: Thanks for the support and help ...  1553888604000  140
# 27   Since SemEval-2019 will be held June 6-7, 2019...  1553879800000  140
# 28   +@aggarwal_kartik.\nCongrats! Wish you many mo...  1553879070000   56
# 29   RT @aggarwal_kartik: Our work (@midasIIITD ) a...  1553879009000  139
# ..                                                 ...            ...  ...
# 311  RT @TensorFlow: TensorFlow 1.10.0 has been rel...  1533794397000  140
# 312  @midasIIITD is looking for motivated IIITD MTe...  1533727856000  140
# 313  @IIITDelhi @ponguru @RatnRajiv The results of ...  1533707628000   96
# 314  RT @IIITDelhi: @midasIIITD has secured rank 1 ...  1533707158000  140
# 315  RT @kdnuggets: Comparison of Top 6 Python NLP ...  1533626193000  103
# 316  Check more details of the 20th IEEE Internatio...  1533607512000  118
# 317  MR2AMC@ISM 2018 will be organized by @RatnRaji...  1533607129000  135
# 318  Our workshop proposal named, "MR2AMC: Multimod...  1533606633000  140
# 319  @NUSComputing Congratulations Abdelhak and Pro...  1533577703000   59
# 320  RT @goodfellow_ian: One of the most anticipate...  1533577619000  123
# 321     @the_dhumketu Great to have you in @midasIIITD  1533535607000   46
# 322  Congratulation @soujanyaporia for being appoin...  1533275793000  140
# 323  @IIITDelhi @the_dhumketu Thanks team @midasIII...  1533124035000   72
# 324  RT @IIITDelhi: Congratulations @midasIIITD int...  1533122407000  140
# 325  RT @learning_pt: Profile of the 5 Indian under...  1533100007000  140
# 326  Have a look at the list of accepted papers in ...  1533039112000  140
# 327  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...  1533002786000  139
# 328  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...  1532935851000  140
# 329  RT @ylecun: Jitendra Malik, who directs FAIR-M...  1532776031000  140
# 330  RT @kdnuggets: .@Bloomberg launches free cours...  1532758449000  140
# 331  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...  1532758428000  124
# 332  RT @IIITDelhi: We are delighted to announce th...  1532750901000  140
# 333  Get ready for the annual technical fest of @II...  1532674004000  140
# 334  Congratulations Dr. @RatnRajiv and team @midas...  1532664451000  139
# 335  Congratulations MIDAS @midasIIITD intern Prakh...  1532495675000  140
# 336    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm  1532428403000   47
# 337  It feels great to be the part of @IIITDelhi. h...  1532427154000   68
# 338  Thank you, @toonzratn for designing the logo o...  1532425586000   78
# 339  We are on Facebook too. Like our page to get o...  1532363105000  121
# 340  MIDAS is a group of researchers at IIIT-Delhi ...  1532350395000  140
#
#      likes  retweets
# 0        0        33
# 1        0        12
# 2        0        15
# 3       13         2
# 4        5         0
# 5        0         0
# 6        0         0
# 7        1         1
# 8        5         2
# 9        4         1
# 10       6         1
# 11       7         1
# 12       0         2
# 13      18         3
# 14      11         1
# 15       0        16
# 16       0        11
# 17       0        59
# 18       0       870
# 19       0        16
# 20       0         4
# 21       8         1
# 22       5         1
# 23       0         7
# 24       7         2
# 25       0        10
# 26       0         2
# 27       9         1
# 28       2         0
# 29       0         1
# ..     ...       ...
# 311      0       265
# 312      2         1
# 313      3         1
# 314      0         1
# 315      0        40
# 316      1         1
# 317      1         1
# 318      1         1
# 319      0         0
# 320      0       103
# 321      0         0
# 322      6         1
# 323      5         1
# 324      0         4
# 325      0         4
# 326      1         0
# 327      0       264
# 328      0         2
# 329      0        57
# 330      0       105
# 331      0         7
# 332      0         6
# 333      3         2
# 334      8         2
# 335      5         1
# 336      2         1
# 337      2         1
# 338      4         1
# 339      3         1
# 340      7         4
#
# [341 rows x 5 columns]
